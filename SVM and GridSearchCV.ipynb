# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pandas as pd

# %%
df = pd.read_csv("cumulative.csv")
df.head(5)
# Out:
#    rowid     kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0      1  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1      2  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2      3  10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 3      4  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      5  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  ...  \
# 0      1.000              0              0              0  ...
# 1      0.969              0              0              0  ...
# 2      0.000              0              1              0  ...
# 3      0.000              0              1              0  ...
# 4      1.000              0              0              0  ...
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0           -81.0      4.467           0.064          -0.096     0.927
# 1           -81.0      4.467           0.064          -0.096     0.927
# 2          -176.0      4.544           0.044          -0.176     0.868
# 3          -174.0      4.564           0.053          -0.168     0.791
# 4          -211.0      4.438           0.070          -0.210     1.046
#
#    koi_srad_err1  koi_srad_err2         ra        dec  koi_kepmag
# 0          0.105         -0.061  291.93423  48.141651      15.347
# 1          0.105         -0.061  291.93423  48.141651      15.347
# 2          0.233         -0.078  297.00482  48.134129      15.436
# 3          0.201         -0.067  285.53461  48.285210      15.597
# 4          0.334         -0.133  288.75488  48.226200      15.509
#
# [5 rows x 50 columns]

# %%
dtypes = pd.DataFrame(df.dtypes)
dtypes
# Out:
#                          0
# rowid                int64
# kepid                int64
# kepoi_name          object
# kepler_name         object
# koi_disposition     object
# koi_pdisposition    object
# koi_score          float64
# koi_fpflag_nt        int64
# koi_fpflag_ss        int64
# koi_fpflag_co        int64
# koi_fpflag_ec        int64
# koi_period         float64
# koi_period_err1    float64
# koi_period_err2    float64
# koi_time0bk        float64
# koi_time0bk_err1   float64
# koi_time0bk_err2   float64
# koi_impact         float64
# koi_impact_err1    float64
# koi_impact_err2    float64
# koi_duration       float64
# koi_duration_err1  float64
# koi_duration_err2  float64
# koi_depth          float64
# koi_depth_err1     float64
# koi_depth_err2     float64
# koi_prad           float64
# koi_prad_err1      float64
# koi_prad_err2      float64
# koi_teq            float64
# koi_teq_err1       float64
# koi_teq_err2       float64
# koi_insol          float64
# koi_insol_err1     float64
# koi_insol_err2     float64
# koi_model_snr      float64
# koi_tce_plnt_num   float64
# koi_tce_delivname   object
# koi_steff          float64
# koi_steff_err1     float64
# koi_steff_err2     float64
# koi_slogg          float64
# koi_slogg_err1     float64
# koi_slogg_err2     float64
# koi_srad           float64
# koi_srad_err1      float64
# koi_srad_err2      float64
# ra                 float64
# dec                float64
# koi_kepmag         float64

# %%
data = df.dropna(axis='columns', how='any')
data.head()
# Out:
#    rowid     kepid kepoi_name koi_disposition koi_pdisposition  koi_fpflag_nt  \
# 0      1  10797460  K00752.01       CONFIRMED        CANDIDATE              0
# 1      2  10797460  K00752.02       CONFIRMED        CANDIDATE              0
# 2      3  10811496  K00753.01  FALSE POSITIVE   FALSE POSITIVE              0
# 3      4  10848459  K00754.01  FALSE POSITIVE   FALSE POSITIVE              0
# 4      5  10854555  K00755.01       CONFIRMED        CANDIDATE              0
#
#    koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  koi_time0bk  \
# 0              0              0              0    9.488036   170.538750
# 1              0              0              0   54.418383   162.513840
# 2              1              0              0   19.899140   175.850252
# 3              1              0              0    1.736952   170.307565
# 4              0              0              0    2.525592   171.595550
#
#    koi_duration         ra        dec
# 0       2.95750  291.93423  48.141651
# 1       4.50700  291.93423  48.141651
# 2       1.78220  297.00482  48.134129
# 3       2.40641  285.53461  48.285210
# 4       1.65450  288.75488  48.226200

# %%
pd.set_option('display.max_columns', None)
# df = df.drop(['rowid', 'kepid','kepoi_name', 'kepler_name', 'koi_pdisposition','koi_tce_delivname','koi_period_err1','koi_period_err2',], axis=1)
# df = df.drop(['rowid', 'kepid','kepoi_name', 'kepler_name', 'koi_pdisposition','koi_tce_delivname','koi_teq_err2', 'koi_teq_err1','koi_depth_err1','koi_depth_err2', 'koi_depth','koi_period_err1', 'koi_period_err2', 'koi_time0bk_err1','koi_time0bk_err2','koi_prad_err1','koi_prad_err2'], axis=1)
data = df.dropna(axis='columns', how='any')
data = data.drop(['rowid', 'kepid', 'kepoi_name','koi_pdisposition'], axis=1)
target = df["koi_disposition"]
target_names = target.unique()
data = data.drop("koi_disposition", axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
from sklearn.preprocessing import StandardScaler

x_scaler = StandardScaler().fit(X_train)
scaled_x_train = x_scaler.transform(X_train)
scaled_x_test = x_scaler.transform(X_test)

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(scaled_x_train, encoded_y_train)
predictions = model.predict(scaled_x_test)

# %%
model.score(scaled_x_train, encoded_y_train)
# Out:
# 0.7837724801338353

# %%
model.score(scaled_x_test, encoded_y_test)
# Out:
# 0.7728983688833124

# %%
from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions,
                           target_names = target_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.74      0.17      0.28       567
# FALSE POSITIVE       0.52      0.93      0.67       574
#      CANDIDATE       0.98      0.97      0.98      1250
#
#       accuracy                           0.77      2391
#      macro avg       0.75      0.69      0.64      2391
#   weighted avg       0.81      0.77      0.74      2391

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
grid.fit(scaled_x_train, encoded_y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END .................C=1, gamma=0.0001;, score=0.783 total time=   0.8s
# [CV 2/5] END .................C=1, gamma=0.0001;, score=0.782 total time=   0.5s
# [CV 3/5] END .................C=1, gamma=0.0001;, score=0.786 total time=   0.5s
# [CV 4/5] END .................C=1, gamma=0.0001;, score=0.794 total time=   0.5s
# [CV 5/5] END .................C=1, gamma=0.0001;, score=0.775 total time=   0.5s
# [CV 1/5] END .................C=1, gamma=0.0005;, score=0.783 total time=   0.5s
# [CV 2/5] END .................C=1, gamma=0.0005;, score=0.782 total time=   0.5s
# [CV 3/5] END .................C=1, gamma=0.0005;, score=0.786 total time=   0.5s
# [CV 4/5] END .................C=1, gamma=0.0005;, score=0.794 total time=   0.5s
# [CV 5/5] END .................C=1, gamma=0.0005;, score=0.775 total time=   0.5s
# [CV 1/5] END ..................C=1, gamma=0.001;, score=0.783 total time=   0.6s
# [CV 2/5] END ..................C=1, gamma=0.001;, score=0.782 total time=   0.5s
# [CV 3/5] END ..................C=1, gamma=0.001;, score=0.786 total time=   0.6s
# [CV 4/5] END ..................C=1, gamma=0.001;, score=0.794 total time=   0.6s
# [CV 5/5] END ..................C=1, gamma=0.001;, score=0.775 total time=   0.7s
# [CV 1/5] END ..................C=1, gamma=0.005;, score=0.783 total time=   0.6s
# [CV 2/5] END ..................C=1, gamma=0.005;, score=0.782 total time=   0.5s
# [CV 3/5] END ..................C=1, gamma=0.005;, score=0.786 total time=   0.5s
# [CV 4/5] END ..................C=1, gamma=0.005;, score=0.794 total time=   0.4s
# [CV 5/5] END ..................C=1, gamma=0.005;, score=0.775 total time=   0.5s
# [CV 1/5] END .................C=5, gamma=0.0001;, score=0.778 total time=   0.5s
# [CV 2/5] END .................C=5, gamma=0.0001;, score=0.786 total time=   0.5s
# [CV 3/5] END .................C=5, gamma=0.0001;, score=0.787 total time=   0.5s
# [CV 4/5] END .................C=5, gamma=0.0001;, score=0.794 total time=   0.5s
# [CV 5/5] END .................C=5, gamma=0.0001;, score=0.780 total time=   0.6s
# [CV 1/5] END .................C=5, gamma=0.0005;, score=0.778 total time=   0.6s
# [CV 2/5] END .................C=5, gamma=0.0005;, score=0.786 total time=   0.6s
# [CV 3/5] END .................C=5, gamma=0.0005;, score=0.787 total time=   0.5s
# [CV 4/5] END .................C=5, gamma=0.0005;, score=0.794 total time=   0.5s
# [CV 5/5] END .................C=5, gamma=0.0005;, score=0.780 total time=   0.5s
# [CV 1/5] END ..................C=5, gamma=0.001;, score=0.778 total time=   0.5s
# [CV 2/5] END ..................C=5, gamma=0.001;, score=0.786 total time=   0.5s
# [CV 3/5] END ..................C=5, gamma=0.001;, score=0.787 total time=   0.5s
# [CV 4/5] END ..................C=5, gamma=0.001;, score=0.794 total time=   0.6s
# [CV 5/5] END ..................C=5, gamma=0.001;, score=0.780 total time=   0.6s
# [CV 1/5] END ..................C=5, gamma=0.005;, score=0.778 total time=   0.7s
# [CV 2/5] END ..................C=5, gamma=0.005;, score=0.786 total time=   0.8s
# [CV 3/5] END ..................C=5, gamma=0.005;, score=0.787 total time=   0.7s
# [CV 4/5] END ..................C=5, gamma=0.005;, score=0.794 total time=   0.6s
# [CV 5/5] END ..................C=5, gamma=0.005;, score=0.780 total time=   1.0s
# [CV 1/5] END ................C=10, gamma=0.0001;, score=0.785 total time=   1.2s
# [CV 2/5] END ................C=10, gamma=0.0001;, score=0.789 total time=   0.7s
# [CV 3/5] END ................C=10, gamma=0.0001;, score=0.788 total time=   0.7s
# [CV 4/5] END ................C=10, gamma=0.0001;, score=0.794 total time=   0.6s
# [CV 5/5] END ................C=10, gamma=0.0001;, score=0.780 total time=   0.5s
# [CV 1/5] END ................C=10, gamma=0.0005;, score=0.785 total time=   0.6s
# [CV 2/5] END ................C=10, gamma=0.0005;, score=0.789 total time=   0.6s
# [CV 3/5] END ................C=10, gamma=0.0005;, score=0.788 total time=   0.6s
# [CV 4/5] END ................C=10, gamma=0.0005;, score=0.794 total time=   0.6s
# [CV 5/5] END ................C=10, gamma=0.0005;, score=0.780 total time=   0.5s
# [CV 1/5] END .................C=10, gamma=0.001;, score=0.785 total time=   0.5s
# [CV 2/5] END .................C=10, gamma=0.001;, score=0.789 total time=   0.7s
# [CV 3/5] END .................C=10, gamma=0.001;, score=0.788 total time=   0.7s
# [CV 4/5] END .................C=10, gamma=0.001;, score=0.794 total time=   0.6s
# [CV 5/5] END .................C=10, gamma=0.001;, score=0.780 total time=   0.6s
# [CV 1/5] END .................C=10, gamma=0.005;, score=0.785 total time=   0.6s
# [CV 2/5] END .................C=10, gamma=0.005;, score=0.789 total time=   0.6s
# [CV 3/5] END .................C=10, gamma=0.005;, score=0.788 total time=   0.6s
# [CV 4/5] END .................C=10, gamma=0.005;, score=0.794 total time=   0.6s
# [CV 5/5] END .................C=10, gamma=0.005;, score=0.780 total time=   0.6s
# [CV 1/5] END ................C=50, gamma=0.0001;, score=0.786 total time=   1.1s
# [CV 2/5] END ................C=50, gamma=0.0001;, score=0.786 total time=   0.9s
# [CV 3/5] END ................C=50, gamma=0.0001;, score=0.789 total time=   0.9s
# [CV 4/5] END ................C=50, gamma=0.0001;, score=0.799 total time=   1.0s
# [CV 5/5] END ................C=50, gamma=0.0001;, score=0.785 total time=   1.0s
# [CV 1/5] END ................C=50, gamma=0.0005;, score=0.786 total time=   1.0s
# [CV 2/5] END ................C=50, gamma=0.0005;, score=0.786 total time=   1.0s
# [CV 3/5] END ................C=50, gamma=0.0005;, score=0.789 total time=   1.1s
# [CV 4/5] END ................C=50, gamma=0.0005;, score=0.799 total time=   1.0s
# [CV 5/5] END ................C=50, gamma=0.0005;, score=0.785 total time=   0.9s
# [CV 1/5] END .................C=50, gamma=0.001;, score=0.786 total time=   1.4s
# [CV 2/5] END .................C=50, gamma=0.001;, score=0.786 total time=   1.4s
# [CV 3/5] END .................C=50, gamma=0.001;, score=0.789 total time=   1.6s
# [CV 4/5] END .................C=50, gamma=0.001;, score=0.799 total time=   1.3s
# [CV 5/5] END .................C=50, gamma=0.001;, score=0.785 total time=   1.5s
# [CV 1/5] END .................C=50, gamma=0.005;, score=0.786 total time=   1.1s
# [CV 2/5] END .................C=50, gamma=0.005;, score=0.786 total time=   1.0s
# [CV 3/5] END .................C=50, gamma=0.005;, score=0.789 total time=   1.0s
# [CV 4/5] END .................C=50, gamma=0.005;, score=0.799 total time=   1.1s
# [CV 5/5] END .................C=50, gamma=0.005;, score=0.785 total time=   1.2s
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10, 50],
#                          'gamma': [0.0001, 0.0005, 0.001, 0.005]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 0.0001}

# %%
model = SVC(kernel='linear', C=10, gamma=0.0001)
model.fit(scaled_x_train, encoded_y_train)
predictions = model.predict(scaled_x_test)
print(model.score(scaled_x_test,encoded_y_test))
# Out:
# 0.7724801338352154

# %%
from sklearn.metrics import classification_report
print(classification_report(encoded_y_test, predictions,
                            target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CONFIRMED       0.73      0.18      0.29       567
# FALSE POSITIVE       0.52      0.92      0.67       574
#      CANDIDATE       0.98      0.97      0.98      1250
#
#       accuracy                           0.77      2391
#      macro avg       0.74      0.69      0.64      2391
#   weighted avg       0.81      0.77      0.74      2391
